# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
S20 = pd.read_csv('2019-2020 NBA Player Stats.csv', usecols= ["FULL NAME","MPG","GP", "PPG", "APG","RPG","3PA","DRTG"])
S21 = pd.read_csv('2020-2021 NBA Player Stats.csv', usecols= ["FULL NAME","MPG", "GP","PPG", "APG","RPG","3PA","DRTG"])
S22 = pd.read_csv('2021-2022 NBA Player Stats.csv', usecols= ["FULL NAME","MPG","GP", "PPG", "APG","RPG","3PA","DRTG"])
S23 = pd.read_csv('2022-2023 NBA Player Stats.csv', usecols= ["NAME","MPG", "GP","PPG", "APG","RPG","3PA","DRtg"])

# %%
#Creates Lists of player names (L20-L23)
#LInc are players included in our dataset

L20N = []
L21N = []
L22N = []
L23N = []
LIncN = []

L20M = []
L21M = []
L22M = []
L23M = []
LIncM20 = []
LIncM = []

L20G = []
L21G = []
L22G = []
L23G = []
LIncG20 = []
LIncG = []

L20P = []
L21P = []
L22P = []
L23P = []
LIncP20 = []
LIncP = []

L20A = []
L21A = []
L22A = []
L23A = []
LIncA20 = []
LIncA = []

L20R = []
L21R = []
L22R = []
L23R = []
LIncR20 = []
LIncR = []

L203 = []
L213 = []
L223 = []
L233 = []
LInc320 = []
LInc3 = []

L20D = []
L21D = []
L22D = []
L23D = []
LIncD20 = []
LIncD = []

for ind in S20.index:
    L20N.append(S20["FULL NAME"][ind])
    L20M.append(S20["MPG"][ind])
    L20G.append(S20["GP"][ind])
    L20P.append(S20["PPG"][ind])
    L20A.append(S20["APG"][ind])
    L20R.append(S20["RPG"][ind])
    L203.append(S20["3PA"][ind])
    L20D.append(S20["DRTG"][ind])
for ind in S21.index:
    L21N.append(S21["FULL NAME"][ind])
    L21M.append(S21["MPG"][ind])
    L21G.append(S21["GP"][ind])
    L21P.append(S21["PPG"][ind])
    L21A.append(S21["APG"][ind])
    L21R.append(S21["RPG"][ind])
    L213.append(S21["3PA"][ind])
    L21D.append(S21["DRTG"][ind])
for ind in S22.index:
    L22N.append(S22["FULL NAME"][ind])
    L22M.append(S22["MPG"][ind])
    L22G.append(S22["GP"][ind])
    L22P.append(S22["PPG"][ind])
    L22A.append(S22["APG"][ind])
    L22R.append(S22["RPG"][ind])
    L223.append(S22["3PA"][ind])
    L22D.append(S22["DRTG"][ind])
for ind in S23.index:
    L23N.append(S23["NAME"][ind])
    L23M.append(S23["MPG"][ind])
    L23G.append(S23["GP"][ind])
    L23P.append(S23["PPG"][ind])
    L23A.append(S23["APG"][ind])
    L23R.append(S23["RPG"][ind])
    L233.append(S23["3PA"][ind])
    L23D.append(S23["DRtg"][ind])

# %%
for name in L20N:
    if name in L21N:
        LIncN.append(name)
    elif name in L22N:
        LIncN.append(name)
    elif name in L23N:
        LIncN.append(name)
#print (LIncN)
#print(len(LIncN))
for name in LIncN:
    numApp = 0
    mpg = 0
    gp = 0
    ppg = 0
    apg = 0
    rpg = 0
    pa3 = 0
    DRtg = 0
    LIncM20.append(L20M[L20N.index(name)])
    LIncG20.append(L20G[L20N.index(name)])
    LIncP20.append(L20P[L20N.index(name)])
    LIncA20.append(L20A[L20N.index(name)])
    LIncR20.append(L20R[L20N.index(name)])
    LInc320.append(L203[L20N.index(name)]/L20G[L20N.index(name)])
    LIncD20.append(L20D[L20N.index(name)])
    if name in L21N:
        mpg = mpg + L21M[L21N.index(name)]
        gp = gp + L21G[L21N.index(name)]
        ppg = ppg + L21P[L21N.index(name)]
        apg = apg + L21A[L21N.index(name)]
        rpg = rpg + L21R[L21N.index(name)]
        pa3 = pa3 + L213[L21N.index(name)]
        DRtg = DRtg = L21D[L21N.index(name)]
        numApp = numApp+1
    if name in L22N:
        mpg = mpg + L22M[L22N.index(name)]
        gp = gp + L22G[L22N.index(name)]
        ppg = ppg + L22P[L22N.index(name)]
        apg = apg + L22A[L22N.index(name)]
        rpg = rpg + L22R[L22N.index(name)]
        pa3 = pa3 + L223[L22N.index(name)]
        DRtg = DRtg = L22D[L22N.index(name)]
        numApp = numApp+1
    if name in L23N:
        mpg = mpg + L23M[L23N.index(name)]
        gp = gp + L23G[L23N.index(name)]
        ppg = ppg + L23P[L23N.index(name)]
        apg = apg + L23A[L23N.index(name)]
        rpg = rpg + L23R[L23N.index(name)]
        pa3 = pa3 + L233[L23N.index(name)]
        DRtg = DRtg = L23D[L23N.index(name)]
        numApp = numApp+1
    LIncM.append(mpg/numApp)
    LIncP.append(ppg/numApp)
    LIncA.append(apg/numApp)
    LIncR.append(rpg/numApp)
    LInc3.append(pa3/gp)
    LIncD.append(DRtg/numApp)

# %%
def checkSig(sample_data):
    #With sample_data as a List
    null_mean = 0
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)
    test_statistic = (sample_mean - null_mean) / (sample_std / np.sqrt(len(sample_data)))
    
    return(abs(test_statistic) > 1.96)

# %%
diffPts = []
for ind in range(len(LIncP)):
    diffPts.append(LIncP[ind]-LIncP20[ind])
ptsDict = {"Covid": LIncP20, "Normal": LIncP, "Difference": diffPts}  
ptsDf = pd.DataFrame(ptsDict)
ptsDf.describe(include="all")
#checkSig(diffPts)

#plt.hist(diffPts, bins=20, alpha=0.5, histtype='stepfilled', color='red', edgecolor='none')
#plt.title("Difference in Points (Normal - Bubble)")
#plt.xlabel("Point Differential")
#plt.ylabel("Number of players")
# Out:
#             Covid      Normal  Difference
# count  153.000000  153.000000  153.000000
# mean    10.677124    8.963725   -1.713399
# std      8.252276    8.083046    5.066531
# min      0.000000    0.000000  -17.300000
# 25%      4.000000    2.900000   -4.800000
# 50%      9.100000    6.500000   -1.100000
# 75%     16.500000   13.200000    1.533333
# max     36.300000   34.300000   10.100000

# %%
diffRbs = []
for ind in range(len(LIncR)):
    diffRbs.append(LIncR[ind]-LIncR20[ind])
rbsDict = {"Covid": LIncR20, "Normal": LIncR, "Difference": diffRbs}  
rbsDf = pd.DataFrame(rbsDict)
rbsDf.describe(include="all")
#checkSig(diffRbs)

#plt.hist(diffRbs, bins=20, alpha=0.5, histtype='stepfilled', color='Blue', edgecolor='none')
#plt.title("Difference in Rebounds (Normal - Bubble)")
#plt.xlabel("Rebound Differential")
#plt.ylabel("Number of players")
# Out:
#             Covid      Normal  Difference
# count  153.000000  153.000000  153.000000
# mean     4.220915    3.506863   -0.714052
# std      3.080534    2.920878    1.825176
# min      0.000000    0.000000   -8.050000
# 25%      2.000000    1.200000   -1.666667
# 50%      3.500000    2.666667   -0.600000
# 75%      5.800000    4.800000    0.300000
# max     14.800000   12.766667    4.100000

# %%
diff3Pa = []
for ind in range(len(LInc3)):
    diff3Pa.append(LInc3[ind]-LInc320[ind])
pa3Dict = {"Covid": LInc320, "Normal": LInc3, "Difference": diff3Pa}  
pa3Df = pd.DataFrame(pa3Dict)
pa3Df.describe(include="all")
#checkSig(diff3Pa)

#plt.hist(diff3Pa, bins=20, alpha=0.5, histtype='stepfilled', color='red', edgecolor='none')
#plt.title("Difference in 3 Point attempts (Normal - Bubble)")
#plt.xlabel("Attempt Differential")
#plt.ylabel("Number of players")
# Out:
#             Covid      Normal  Difference
# count  153.000000  153.000000  153.000000
# mean     3.528631    3.041472   -0.487158
# std      2.748876    2.676348    2.039549
# min      0.000000    0.000000   -9.000000
# 25%      1.000000    0.666667   -1.366667
# 50%      3.142857    2.600000   -0.333333
# 75%      5.666667    4.800000    0.586207
# max     10.000000   13.000000    5.069767

# %%
#Has problems
"""diffDef = []
for ind in range(len(LIncD)):
    diffDef.append(LIncD[ind]-LIncD20[ind])
print(len(diffDef))
for et in diffDef:
    print(et)
defDict = {"Covid": LIncD20, "Normal": LIncD, "Difference": diffDef}  
defDf = pd.DataFrame(defDict)
defDf.describe(include="all")
#checkSig(diffDef)

#plt.hist(diffDef, bins=20, alpha=0.5, histtype='stepfilled', color='red', edgecolor='none')
#plt.title("Difference in Defensive Rating (Normal - Bubble)")
#plt.xlabel("Defensive Differential")
#plt.ylabel("Number of players")
"""
# Out:
# 'diffDef = []\nfor ind in range(len(LIncD)):\n    diffDef.append(LIncD[ind]-LIncD20[ind])\nprint(len(diffDef))\nfor et in diffDef:\n    print(et)\ndefDict = {"Covid": LIncD20, "Normal": LIncD, "Difference": diffDef}  \ndefDf = pd.DataFrame(defDict)\ndefDf.describe(include="all")\n#checkSig(diffDef)\n\n#plt.hist(diffDef, bins=20, alpha=0.5, histtype=\'stepfilled\', color=\'red\', edgecolor=\'none\')\n#plt.title("Difference in Defensive Rating (Normal - Bubble)")\n#plt.xlabel("Defensive Differential")\n#plt.ylabel("Number of players")\n'

# %%
diffA = []
for ind in range(len(LIncA)):
    diffA.append(LIncA[ind]-LIncA20[ind])
aDict = {"Covid": LIncA20, "Normal": LIncA, "Difference": diffA}  
aDf = pd.DataFrame(aDict)
aDf.describe(include="all")
#checkSig(diffPts)

#plt.hist(diffPts, bins=20, alpha=0.5, histtype='stepfilled', color='red', edgecolor='none')
#plt.title("Difference in Points (Normal - Bubble)")
#plt.xlabel("Point Differential")
#plt.ylabel("Number of players")
# Out:
#             Covid      Normal  Difference
# count  153.000000  153.000000  153.000000
# mean     2.141830    1.939216   -0.202614
# std      2.131055    2.197106    1.452486
# min      0.000000    0.000000   -7.100000
# 25%      0.600000    0.450000   -0.800000
# 50%      1.300000    1.200000   -0.150000
# 75%      3.100000    2.600000    0.400000
# max     10.000000   10.200000    5.900000

# %%
X = np.array(LIncM20)  # Input features
y = np.array(LIncP20)  # Target variable

# Fit the linear regression model
coefficients = np.polyfit(X, y, 1)  # Fit a first-degree polynomial (linear regression)

slope = coefficients[0]

# Print the slope
print("Slope:", slope)

# Create the regression line
regression_line = np.poly1d(coefficients)  # Create a polynomial function based on the coefficients
x_range = np.linspace(X.min(), X.max(), 100)  # Generate an array of x values within the range of X
y_range = regression_line(x_range)  # Calculate the corresponding y values for the regression line

# Plot the data points and the regression line
plt.scatter(X, y, label='Data Points')  # Plot the data points
plt.plot(x_range, y_range, color='r', label='Regression Line')  # Plot the regression line
plt.xlabel('MPG')  # Add x-axis label
plt.ylabel('PPG')  # Add y-axis label
plt.title('Linear Regression of Bubble')  # Add title
plt.legend()  # Add legend
plt.grid(True)  # Add gridlines
plt.show()  # Display the plot
# Out:
# Slope: 0.5912513284487512

# %%
X = np.array(LIncM)  # Input features
y = np.array(LIncP)  # Target variable

# Fit the linear regression model
coefficients = np.polyfit(X, y, 1)  # Fit a first-degree polynomial (linear regression)

slope = coefficients[0]

# Print the slope
print("Slope:", slope)

# Create the regression line
regression_line = np.poly1d(coefficients)  # Create a polynomial function based on the coefficients
x_range = np.linspace(X.min(), X.max(), 100)  # Generate an array of x values within the range of X
y_range = regression_line(x_range)  # Calculate the corresponding y values for the regression line

# Plot the data points and the regression line
plt.scatter(X, y, label='Data Points')  # Plot the data points
plt.plot(x_range, y_range, color='r', label='Regression Line')  # Plot the regression line
plt.xlabel('MPG')  # Add x-axis label
plt.ylabel('PPG')  # Add y-axis label
plt.title('Linear Regression of Normal Years')  # Add title
plt.legend()  # Add legend
plt.grid(True)  # Add gridlines
plt.show()  # Display the plot
# Out:
# Slope: 0.57405542028991
